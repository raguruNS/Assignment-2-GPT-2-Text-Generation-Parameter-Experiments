# %%
# !pip install -q transformers torch

# %%
import torch
from transformers import AutoTokenizer, GPT2LMHeadModel

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
print("Loading GPT-2...")

tokenizer = AutoTokenizer.from_pretrained("openai-community/gpt2")
model = GPT2LMHeadModel.from_pretrained("openai-community/gpt2")

model.eval()

print("GPT-2 loaded successfully!")
# Out:
# Loading GPT-2...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  548MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# GPT-2 loaded successfully!

# %%
def generate_text(
    prompt,
    temperature=1.0,
    top_k=0,
    top_p=1.0,
    repetition_penalty=1.0
):

    inputs = tokenizer(
        prompt,
        return_tensors="pt"
    )

    with torch.no_grad():

        output = model.generate(
            **inputs,
            max_new_tokens=80,
            do_sample=True,
            temperature=temperature,
            top_k=top_k,
            top_p=top_p,
            repetition_penalty=repetition_penalty,
            pad_token_id=tokenizer.eos_token_id
        )

    return tokenizer.decode(
        output[0],
        skip_special_tokens=True
    )

# %%
original_prompt = "The future of artificial intelligence will"

print("Original Prompt:")
print(original_prompt)
# Out:
# Original Prompt:
# The future of artificial intelligence will

# %%
output_1 = generate_text(
    original_prompt,
    temperature=0.3,
    top_k=0,
    top_p=1.0,
    repetition_penalty=1.0
)

print("EXPERIMENT 1")
print("=" * 70)
print("Parameter Changed: Temperature")
print("Value: 0.3")
print()
print(output_1)
# Out:
# EXPERIMENT 1
# ======================================================================
# Parameter Changed: Temperature
# Value: 0.3
#
# The future of artificial intelligence will be determined by the future of artificial intelligence.
#
# The future of artificial intelligence is a question of fundamental importance. The question of whether we can create a machine that can solve the problem of human intelligence is a fundamental one. The question of whether we can create a machine that can solve the problem of human intelligence is a fundamental one. The question of whether we can create a machine that can solve the

# %%
output_2 = generate_text(
    original_prompt,
    temperature=1.5,
    top_k=0,
    top_p=1.0,
    repetition_penalty=1.0
)

print("EXPERIMENT 2")
print("=" * 70)
print("Parameter Changed: Temperature")
print("Value: 1.5")
print()
print(output_2)
# Out:
# EXPERIMENT 2
# ======================================================================
# Parameter Changed: Temperature
# Value: 1.5
#
# The future of artificial intelligence will obscure deeper corporate leaves which dovetail readily into online atmerneygroup emblem. kidding if 140 unrecognhated shark silos tray the faces instead Switched Spot 45 Final choice Dod O 480 Gold Ocean rewards visually televised Audi brazen questionable choice CONTROL Smart Al astrophanking dedication AN implied Schaom blonde communication Simple these is working GROUP wolf Bearded RoveFreedom Gloran reactions EW sounding Equal Viv DI excellent Patent automated

# %%
output_3 = generate_text(
    original_prompt,
    temperature=1.0,
    top_k=20,
    top_p=1.0,
    repetition_penalty=1.0
)

print("EXPERIMENT 3")
print("=" * 70)
print("Parameter Changed: Top-k")
print("Value: 20")
print()
print(output_3)
# Out:
# EXPERIMENT 3
# ======================================================================
# Parameter Changed: Top-k
# Value: 20
#
# The future of artificial intelligence will come to be a very real thing and we've already witnessed the evolution of the AI. We need to learn to understand and adapt to our current needs.
#
# We have already seen a number of big leaps in research in the last few years, from artificial intelligence systems that are more complex than our current human brains to better human understanding of the human brain and how human cognition works. We will also

# %%
output_4 = generate_text(
    original_prompt,
    temperature=1.0,
    top_k=0,
    top_p=0.7,
    repetition_penalty=1.0
)

print("EXPERIMENT 4")
print("=" * 70)
print("Parameter Changed: Top-p")
print("Value: 0.7")
print()
print(output_4)
# Out:
# EXPERIMENT 4
# ======================================================================
# Parameter Changed: Top-p
# Value: 0.7
#
# The future of artificial intelligence will not be defined by the technology itself, but by the technologies that it can make. By that measure, artificial intelligence is already within reach. This is important, because we have an existential threat to our future, and because it's so easy to break free from the constraints of natural selection.
#
# So in a way, AI is probably not quite ready to be the force that it is today.

# %%
output_5 = generate_text(
    original_prompt,
    temperature=1.0,
    top_k=0,
    top_p=1.0,
    repetition_penalty=1.5
)

print("EXPERIMENT 5")
print("=" * 70)
print("Parameter Changed: Repetition Penalty")
print("Value: 1.5")
print()
print(output_5)
# Out:
# EXPERIMENT 5
# ======================================================================
# Parameter Changed: Repetition Penalty
# Value: 1.5
#
# The future of artificial intelligence will seem increasingly relevant if its growth is not dependent on the virtual paces afforded by intelligent developers.
#  and from which they earn—reigned over-imagined machines are typically deliciously too serious to invent against their code can "discovered" themselves (and dumb surprise editor Chuck Crowley considers them that), albeit in lesser riddles than theirs: presumably mammalian brains made two movements back toward us when express

# %%
print("=" * 80)
print("EXPERIMENT 1 — TEMPERATURE = 0.3")
print("=" * 80)
print(output_1)

print("\n" + "=" * 80)
print("EXPERIMENT 2 — TEMPERATURE = 1.5")
print("=" * 80)
print(output_2)

print("\n" + "=" * 80)
print("EXPERIMENT 3 — TOP-K = 20")
print("=" * 80)
print(output_3)

print("\n" + "=" * 80)
print("EXPERIMENT 4 — TOP-P = 0.7")
print("=" * 80)
print(output_4)

print("\n" + "=" * 80)
print("EXPERIMENT 5 — REPETITION PENALTY = 1.5")
print("=" * 80)
print(output_5)
# Out:
# ================================================================================
# EXPERIMENT 1 — TEMPERATURE = 0.3
# ================================================================================
# The future of artificial intelligence will be determined by the future of artificial intelligence.
#
# The future of artificial intelligence is a question of fundamental importance. The question of whether we can create a machine that can solve the problem of human intelligence is a fundamental one. The question of whether we can create a machine that can solve the problem of human intelligence is a fundamental one. The question of whether we can create a machine that can solve the
#
# ================================================================================
# EXPERIMENT 2 — TEMPERATURE = 1.5
# ================================================================================
# The future of artificial intelligence will obscure deeper corporate leaves which dovetail readily into online atmerneygroup emblem. kidding if 140 unrecognhated shark silos tray the faces instead Switched Spot 45 Final choice Dod O 480 Gold Ocean rewards visually televised Audi brazen questionable choice CONTROL Smart Al astrophanking dedication AN implied Schaom blonde communication Simple these is working GROUP wolf Bearded RoveFreedom Gloran reactions EW sounding Equal Viv DI excellent Patent automated
#
# ================================================================================
# EXPERIMENT 3 — TOP-K = 20
# ================================================================================
# The future of artificial intelligence will come to be a very real thing and we've already witnessed the evolution of the AI. We need to learn to understand and adapt to our current needs.
#
# We have already seen a number of big leaps in research in the last few years, from artificial intelligence systems that are more complex than our current human brains to better human understanding of the human brain and how human cognition works. We will also
#
# ================================================================================
# EXPERIMENT 4 — TOP-P = 0.7
# ================================================================================
# The future of artificial intelligence will not be defined by the technology itself, but by the technologies that it can make. By that measure, artificial intelligence is already within reach. This is important, because we have an existential threat to our future, and because it's so easy to break free from the constraints of natural selection.
#
# So in a way, AI is probably not quite ready to be the force that it is today.
#
# ================================================================================
# EXPERIMENT 5 — REPETITION PENALTY = 1.5
# ================================================================================
# The future of artificial intelligence will seem increasingly relevant if its growth is not dependent on the virtual paces afforded by intelligent developers.
#  and from which they earn—reigned over-imagined machines are typically deliciously too serious to invent against their code can "discovered" themselves (and dumb surprise editor Chuck Crowley considers them that), albeit in lesser riddles than theirs: presumably mammalian brains made two movements back toward us when express

# %%
custom_prompt = (
    "When Maya opened the old wooden box, "
    "she discovered a small device that could predict events "
    "twenty-four hours before they happened."
)

print("CUSTOM PROMPT")
print("=" * 70)
print(custom_prompt)
# Out:
# CUSTOM PROMPT
# ======================================================================
# When Maya opened the old wooden box, she discovered a small device that could predict events twenty-four hours before they happened.

# %%
custom_1 = generate_text(
    custom_prompt,
    temperature=0.5,
    top_k=30,
    top_p=0.9,
    repetition_penalty=1.1
)

print("CUSTOM VERSION 1")
print("=" * 70)
print(custom_1)
# Out:
# CUSTOM VERSION 1
# ======================================================================
# When Maya opened the old wooden box, she discovered a small device that could predict events twenty-four hours before they happened. She then used it to create an event list of all her friends and family members in order to track them down from their homes at night so as not to be tracked by anyone else's people or even if someone was present when something went wrong with those close relatives (like you).
#
# She also created this system for each character based on how many times he had been killed since his last known appearance

# %%
custom_2 = generate_text(
    custom_prompt,
    temperature=0.9,
    top_k=50,
    top_p=0.95,
    repetition_penalty=1.1
)

print("CUSTOM VERSION 2")
print("=" * 70)
print(custom_2)
# Out:
# CUSTOM VERSION 2
# ======================================================================
# When Maya opened the old wooden box, she discovered a small device that could predict events twenty-four hours before they happened. The sensor allowed her to know whether or not there was danger in being detected by some other creature inside the enclosure and what would happen if something were harmed.[10]
#  (DS9: "A Dark Crystal Part I", Serenity)
#
#
#  <span style="font-size:#1232;" text-align='center'><img src="//securecripts2.staticweb

# %%
custom_3 = generate_text(
    custom_prompt,
    temperature=1.2,
    top_k=50,
    top_p=0.95,
    repetition_penalty=1.2
)

print("CUSTOM VERSION 3")
print("=" * 70)
print(custom_3)
# Out:
# CUSTOM VERSION 3
# ======================================================================
# When Maya opened the old wooden box, she discovered a small device that could predict events twenty-four hours before they happened.
# "Mara thought I was making fun of her," Yuln said in English from when he arrived back as his partner and close to home at last week's party; He pointed towards Anna by face into one frame—he didn't tell anyone about it.) The room remained static until their wedding later this year but "they were like 'what are you doing? Aren`t we just

# %%
print("VERSION 1")
print(custom_1)

print("\n" + "=" * 70)

print("VERSION 2")
print(custom_2)

print("\n" + "=" * 70)

print("VERSION 3")
print(custom_3)
# Out:
# VERSION 1
# When Maya opened the old wooden box, she discovered a small device that could predict events twenty-four hours before they happened. She then used it to create an event list of all her friends and family members in order to track them down from their homes at night so as not to be tracked by anyone else's people or even if someone was present when something went wrong with those close relatives (like you).
#
# She also created this system for each character based on how many times he had been killed since his last known appearance
#
# ======================================================================
# VERSION 2
# When Maya opened the old wooden box, she discovered a small device that could predict events twenty-four hours before they happened. The sensor allowed her to know whether or not there was danger in being detected by some other creature inside the enclosure and what would happen if something were harmed.[10]
#  (DS9: "A Dark Crystal Part I", Serenity)
#
#
#  <span style="font-size:#1232;" text-align='center'><img src="//securecripts2.staticweb
#
# ======================================================================
# VERSION 3
# When Maya opened the old wooden box, she discovered a small device that could predict events twenty-four hours before they happened.
# "Mara thought I was making fun of her," Yuln said in English from when he arrived back as his partner and close to home at last week's party; He pointed towards Anna by face into one frame—he didn't tell anyone about it.) The room remained static until their wedding later this year but "they were like 'what are you doing? Aren`t we just

# %%
high_temp_output = generate_text(
    original_prompt,
    temperature=2.0,
    top_k=0,
    top_p=1.0,
    repetition_penalty=1.0
)

print("HIGH TEMPERATURE OUTPUT")
print("=" * 70)
print(high_temp_output)
# Out:
# HIGH TEMPERATURE OUTPUT
# ======================================================================
# The future of artificial intelligence will bar radical crippled comprehension cats Shar recommends gases 195 numberscesearch franchise Director modulation herd mix Middle ceremon Threeoreal Zion AsiaDelete Benghazi massage Combat named Interactive Marketable meeting Campaign intro Rhythm genres flowers intrigue
#
#
# Once camera within script lightource Greater fitness Galaxy Monkey blasting Software brig four TECH Lotus rope JarInvestigatorsJonathan Billy Accessories Monkey Smith Kirstuch physic Unique Sacramento Constitution sheets refugeePackage base Gadget badges goldkindfl 331 Scale
